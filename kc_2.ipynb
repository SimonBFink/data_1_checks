# %%
#Load the .csv file

#Import pandas
import pandas as pd

#Read the .csv in a dataframe (df)

df = pd.read_csv("assets/Strings Library - Ensemble Music.csv")

#Display partial .csv file to check if it worked. 
df
# Out:
#     Composer First Name Composer Last Name       Arranger  \
# 0                   NaN                NaN            NaN
# 1                   NaN                NaN            NaN
# 2                   NaN                NaN            NaN
# 3                   NaN                NaN            NaN
# 4                   NaN                NaN            NaN
# ..                  ...                ...            ...
# 158             Nikolai    Rimsky-Korsakov  Sandra Dackow
# 159              Johann          Pachelbel     Simon Fink
# 160                J.S.               Bach            NaN
# 161    Wolfgang Amadeus             Mozart             CM
# 162              Walter           Cummings            NaN
#
#                                            Title  Grade   Instrumentation  \
# 0                        A Holly Jolly Christmas    1.0               NaN
# 1                          A Vivaldi School Year    1.5               NaN
# ...

# %%
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt


df['Grade'].value_counts(sort=False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd 
import seaborn as sns

df = pd.read_csv("assets/Strings Library - Ensemble Music.csv")
df.head()

sns.scatterplot(x=df['Grade'],
                y=df['Collection'])
# Out:
# <AxesSubplot:xlabel='Grade', ylabel='Collection'>
